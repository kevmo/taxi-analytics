# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
import pandas as pd
import requests
import io

# The URL of the Parquet file
url = 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-11.parquet'

# Fetch the Parquet file
response = requests.get(url)
response.raise_for_status()  # This will raise an error if the download failed

# Read the Parquet content into a pandas DataFrame
df = pd.read_parquet(io.BytesIO(response.content))

# Now you've got your DataFrame, do some data wrangling or just admire its beauty
print(df.head())
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-11-01 00:03:03   2023-11-01 01:04:08              2.0
# 1         1  2023-11-01 00:03:28   2023-11-01 00:23:59              0.0
# 2         2  2023-10-31 23:58:05   2023-11-01 00:54:03              4.0
# 3         2  2023-11-01 00:03:50   2023-11-01 00:04:59              1.0
# 4         2  2023-11-01 00:06:30   2023-11-01 00:14:25              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          13.60         1.0                  N           132            26
# 1           3.50         1.0                  N           140             7
# 2          18.61         2.0                  N           132           230
# 3           0.39         1.0                  N           236           236
# 4           1.20         1.0                  N           236           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2         61.8   2.75      0.5        0.00          0.00
# 1             1         20.5   3.50      0.5        5.10          0.00
# 2             1         70.0   0.00      0.5       16.54          6.94
# 3             1          4.4   1.00      0.5        1.88          0.00
# 4             1         10.0   1.00      0.5        3.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         66.05                   0.0         1.75
# 1                    1.0         30.60                   2.5         0.00
# 2                    1.0         99.23                   2.5         1.75
# 3                    1.0         11.28                   2.5         0.00
# 4                    1.0         18.00                   2.5         0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3339715 entries, 0 to 3339714
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# memory usage: 445.9+ MB

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-11-01 00:03:03   2023-11-01 01:04:08              2.0
# 1               1  2023-11-01 00:03:28   2023-11-01 00:23:59              0.0
# 2               2  2023-10-31 23:58:05   2023-11-01 00:54:03              4.0
# 3               2  2023-11-01 00:03:50   2023-11-01 00:04:59              1.0
# 4               2  2023-11-01 00:06:30   2023-11-01 00:14:25              1.0
# ...           ...                  ...                   ...              ...
# 3339710         2  2023-11-30 23:39:21   2023-12-01 00:05:10              NaN
# 3339711         2  2023-11-30 23:01:55   2023-11-30 23:03:06              NaN
# 3339712         2  2023-11-30 23:23:16   2023-11-30 23:33:56              NaN
# 3339713         2  2023-11-30 23:39:22   2023-11-30 23:53:33              NaN
# 3339714         2  2023-11-30 23:13:48   2023-11-30 23:37:11              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                13.60         1.0                  N           132
# 1                 3.50         1.0                  N           140
# 2                18.61         2.0                  N           132
# 3                 0.39         1.0                  N           236
# 4                 1.20         1.0                  N           236
# ...                ...         ...                ...           ...
# 3339710           4.15         NaN               None           161
# 3339711           0.00         NaN               None           232
# 3339712           1.74         NaN               None           113
# 3339713           2.39         NaN               None            90
# 3339714           3.38         NaN               None           114
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  26             2        61.80   2.75      0.5        0.00
# 1                   7             1        20.50   3.50      0.5        5.10
# 2                 230             1        70.00   0.00      0.5       16.54
# 3                 236             1         4.40   1.00      0.5        1.88
# 4                 141             1        10.00   1.00      0.5        3.00
# ...               ...           ...          ...    ...      ...         ...
# 3339710           146             0        24.30   0.00      0.5        5.66
# 3339711           232             0        22.42   0.00      0.5        5.14
# 3339712           186             0        16.09   0.00      0.5        0.00
# 3339713           144             0        16.23   0.00      0.5        0.00
# 3339714           142             0        27.95   0.00      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         66.05
# 1                0.00                    1.0         30.60
# 2                6.94                    1.0         99.23
# 3                0.00                    1.0         11.28
# 4                0.00                    1.0         18.00
# ...               ...                    ...           ...
# 3339710          0.00                    1.0         33.96
# 3339711          0.00                    1.0         31.56
# 3339712          0.00                    1.0         20.09
# 3339713          0.00                    1.0         20.23
# 3339714          0.00                    1.0         31.95
#
#          congestion_surcharge  Airport_fee
# 0                         0.0         1.75
# 1                         2.5         0.00
# 2                         2.5         1.75
# 3                         2.5         0.00
# 4                         2.5         0.00
# ...                       ...          ...
# 3339710                   NaN          NaN
# 3339711                   NaN          NaN
# 3339712                   NaN          NaN
# 3339713                   NaN          NaN
# 3339714                   NaN          NaN
#
# [3339715 rows x 19 columns]

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "Airport_fee" REAL
# )

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" INTEGER,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" INTEGER,
# 	"DOLocationID" INTEGER,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
len(df)
# Out:
# 3339715

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# Define chunk size
chunk_size = 100000

# Number of chunks to upload - ceil division to handle the last chunk if it's smaller than chunk_size
num_chunks = -(-len(df) // chunk_size)

print(f"Starting upload of {len(df)} rows in {num_chunks} chunks...")

# Upload in chunks
for i in range(num_chunks):
    start_index = i * chunk_size
    end_index = start_index + chunk_size
    chunk = df.iloc[start_index:end_index]
    chunk.to_sql('yellow_taxi_data', con=engine, if_exists='append', index=False)
    print(f"Uploaded chunk {i+1}/{num_chunks}")

print("Upload complete!")
# Out:
# Starting upload of 3339715 rows in 34 chunks...
# Uploaded chunk 1/34
# Uploaded chunk 2/34
# Uploaded chunk 3/34
# Uploaded chunk 4/34
# Uploaded chunk 5/34
# Uploaded chunk 6/34
# Uploaded chunk 7/34
# Uploaded chunk 8/34
# Uploaded chunk 9/34
# Uploaded chunk 10/34
# Uploaded chunk 11/34
# Uploaded chunk 12/34
# Uploaded chunk 13/34
# Uploaded chunk 14/34
# Uploaded chunk 15/34
# Uploaded chunk 16/34
# Uploaded chunk 17/34
# Uploaded chunk 18/34
# Uploaded chunk 19/34
# Uploaded chunk 20/34
# Uploaded chunk 21/34
# Uploaded chunk 22/34
# Uploaded chunk 23/34
# Uploaded chunk 24/34
# Uploaded chunk 25/34
# Uploaded chunk 26/34
# Uploaded chunk 27/34
# Uploaded chunk 28/34
# Uploaded chunk 29/34
# Uploaded chunk 30/34
# Uploaded chunk 31/34
# Uploaded chunk 32/34
# Uploaded chunk 33/34
# Uploaded chunk 34/34
# Upload complete!

# %% [markdown]
# # Connecting Jupyter nb to postgres

# %%
engine.connect()

# %%
query = "SELECT COUNT(*) FROM yellow_taxi_data;"

pd.read_sql(query, con=engine)
# Out:
#      count
# 0  3339715

# %% [markdown]
# # Zones

# %%
url = "https://d37ci6vzurychx.cloudfront.net/misc/taxi+_zone_lookup.csv"

zones_df = pd.read_csv(url)

# %%
zones_df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
zones_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          264 non-null    object
#  3   service_zone  263 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB

# %%
print(pd.io.sql.get_schema(df, name="zones", con=engine))
# Out:
# CREATE TABLE zones (
# 	"VendorID" INTEGER,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" INTEGER,
# 	"DOLocationID" INTEGER,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	"Airport_fee" FLOAT(53)
# )

# %%
df.head(n=0).to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.head(n=0).to_sql(name='zones', con=engine, if_exists='replace')
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/pandas/core/generic.py:3081, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3077 [(1,), (None,), (2,)]
#    3078 """  # noqa: E501
#    3079 from pandas.io import sql
# -> 3081 return sql.to_sql(
#    3082     self,
#    3083     name,
#    3084     con,
#    3085     schema=schema,
#    3086     if_exists=if_exists,
#    3087     index=index,
#    3088     index_label=index_label,
#    3089     chunksize=chunksize,
#    3090     dtype=dtype,
#    3091     method=method,
#    3092 )
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/pandas/io/sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836 elif not isinstance(frame, DataFrame):
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
# --> 841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#    (...)
#     853         **engine_kwargs,
#     854     )
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/pandas/io/sql.py:1648, in SQLDatabase.__exit__(self, *args)
#    1646 def __exit__(self, *args) -> None:
#    1647     if not self.returns_generator:
# -> 1648         self.exit_stack.close()
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:597, in ExitStack.close(self)
#     595 def close(self):
#     596     """Immediately unwind the context stack."""
# --> 597     self.__exit__(None, None, None)
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:589, in ExitStack.__exit__(self, *exc_details)
#     585 try:
#     586     # bare "raise exc_details[1]" replaces our carefully
#     587     # set-up context
#     588     fixed_ctx = exc_details[1].__context__
# --> 589     raise exc_details[1]
#     590 except BaseException:
#     591     exc_details[1].__context__ = fixed_ctx
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:574, in ExitStack.__exit__(self, *exc_details)
#     572 assert is_sync
#     573 try:
# --> 574     if cb(*exc_details):
#     575         suppressed_exc = True
#     576         pending_raise = False
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/util.py:146, in TransactionalContext.__exit__(self, type_, value, traceback)
#     144     self.commit()
#     145 except:
# --> 146     with util.safe_reraise():
#     147         if self._rollback_can_be_called():
#     148             self.rollback()
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/util.py:144, in TransactionalContext.__exit__(self, type_, value, traceback)
#     142 if type_ is None and self._transaction_is_active():
#     143     try:
# --> 144         self.commit()
#     145     except:
#     146         with util.safe_reraise():
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2611, in Transaction.commit(self)
#    2595 """Commit this :class:`.Transaction`.
#    2596
#    2597 The implementation of this may vary based on the type of transaction in
#    (...)
#    2608
#    2609 """
#    2610 try:
# -> 2611     self._do_commit()
#    2612 finally:
#    2613     assert not self.is_active
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2716, in RootTransaction._do_commit(self)
#    2713 assert self.connection._transaction is self
#    2715 try:
# -> 2716     self._connection_commit_impl()
#    2717 finally:
#    2718     # whether or not commit succeeds, cancel any
#    2719     # nested transactions, make this transaction "inactive"
#    2720     # and remove it as a reset agent
#    2721     if self.connection._nested_transaction:
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2687, in RootTransaction._connection_commit_impl(self)
#    2686 def _connection_commit_impl(self) -> None:
# -> 2687     self.connection._commit_impl()
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1136, in Connection._commit_impl(self)
#    1134     self.engine.dialect.do_commit(self.connection)
#    1135 except BaseException as e:
# -> 1136     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2338, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2336     else:
#    2337         assert exc_info[1] is not None
# -> 2338         raise exc_info[1].with_traceback(exc_info[2])
#    2339 finally:
#    2340     del self._reentrant_error
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1134, in Connection._commit_impl(self)
#    1132         self._log_info("COMMIT")
#    1133 try:
# -> 1134     self.engine.dialect.do_commit(self.connection)
#    1135 except BaseException as e:
#    1136     self._handle_dbapi_exception(e, None, None, None, None)
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:575, in Connection.connection(self)
#     573 if self._dbapi_connection is None:
#     574     try:
# --> 575         return self._revalidate_connection()
#     576     except (exc.PendingRollbackError, exc.ResourceClosedError):
#     577         raise
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:667, in Connection._revalidate_connection(self)
#     665 if self.__can_reconnect and self.invalidated:
#     666     if self._transaction is not None:
# --> 667         self._invalid_transaction()
#     668     self._dbapi_connection = self.engine.raw_connection()
#     669     return self._dbapi_connection
#
# File ~/.local/share/virtualenvs/taxi-analytics-HoQpuw9I/lib/python3.11/site-packages/sqlalchemy/engine/base.py:657, in Connection._invalid_transaction(self)
#     656 def _invalid_transaction(self) -> NoReturn:
# --> 657     raise exc.PendingRollbackError(
#     658         "Can't reconnect until invalid %stransaction is rolled "
#     659         "back.  Please rollback() fully before proceeding"
#     660         % ("savepoint " if self._nested_transaction is not None else ""),
#     661         code="8s2b",
#     662     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)
